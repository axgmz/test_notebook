# %% [markdown]
# # Run Lammps

# %%
from lammps import lammps

# %%
lmp = lammps()
# Out:
# LAMMPS (23 Jun 2022 - Update 1)
# OMP_NUM_THREADS environment is not set. Defaulting to 1 thread. (src/comm.cpp:98)
#   using 1 OpenMP thread(s) per MPI task
# Loaded 1 plugins from /srv/conda/envs/notebook/lib/deepmd_lmp
# Loaded 0 plugins from

# %%
lmp.file("in.lmp")
# Out:
# Reading data file ...
#   orthogonal box = (0 0 0) to (16.1 16.1 16.1)
#   1 by 1 by 1 MPI processor grid
#   reading atoms ...
#   432 atoms
#   reading velocities ...
#   432 velocities
#   read_data CPU = 0.024 seconds
# Summary of lammps deepmd module ...
#   >>> Info of deepmd-kit:
#   installed to:       /srv/conda/envs/notebook
#   source:             v2.1.4
#   source branch:       HEAD
#   source commit:      c3933924
#   source commit at:   2022-08-19 12:09:24 +0800
#   surpport model ver.:1.1
#   build float prec:   double
#   build variant:      cpu
#   build with tf inc:  /srv/conda/envs/notebook/include;/srv/conda/envs/notebook/include
#   build with tf lib:  /srv/conda/envs/notebook/lib/libtensorflow_cc.so;/srv/conda/envs/notebook/lib/libtensorflow_framework.so
#   set tf intra_op_parallelism_threads: -1
#   set tf inter_op_parallelism_threads: -1
#   >>> Info of lammps module:
#   use deepmd-kit at:  /srv/conda/envs/notebook
# ...
